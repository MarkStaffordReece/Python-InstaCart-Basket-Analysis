# %%
#4.6 Final Task

import pandas as pd
import numpy as np
import os
path = 'C:\\Users\\reece\\InstaCart Basket Analysis 4.4.23\\Data\\'

df_merged = pd.read_csv(os.path.join(path, 'Prepared Data', 'orderswrangledv1.csv'), index_col=False)
path = r"C:\Users\reece\InstaCart Basket Analysis 4.4.23\Data\Prepared Data\orders_products_combined.pkl"
df_ords_prods_combined = pd.read_pickle(path)

# %%
df_merged.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0             0           0   2539329        1    prior             1
# 1             1           1   2398795        1    prior             2
# 2             2           2    473747        1    prior             3
# 3             3           3   2254736        1    prior             4
# 4             4           4    431534        1    prior             5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order
# 0                   2                  8                     NaN
# 1                   3                  7                    15.0
# 2                   3                 12                    21.0
# 3                   4                  7                    29.0
# 4                   4                 15                    28.0

# %%
df_merged = df_merged.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis=1)

# %%
df_merged.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
df_ords_prods_combined.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
df_ords_prods_combined.shape
# Out:
# (9927471, 10)

# %%
Determine a suitable way to combine the orders_products_combined dataframe
with your products data set. Make sure you’re using your wrangled, cleaned, 
and deduped products data set stored in your “Prepared Data” folder from the previous Exercise’s task.

# %%
df_merged_large = df_ords_prods_combined.merge(df_merged, on=['order_id', 'user_id'])

# %%
df_merged_large.head()

# %%
df_merged_large.head()
# Out:
#    order_id  user_id  order_number_x  orders_day_of_week_x  \
# 0   2539329        1               1                     2
# 1   2539329        1               1                     2
# 2   2539329        1               1                     2
# 3   2539329        1               1                     2
# 4   2539329        1               1                     2
#
#    order_hour_of_day_x  days_since_prior_order_x  product_id  \
# 0                    8                       NaN         196
# 1                    8                       NaN       14084
# 2                    8                       NaN       12427
# 3                    8                       NaN       26088
# 4                    8                       NaN       26405
#
#    add_to_cart_order  reordered _merge eval_set  order_number_y  \
# 0                  1          0   both    prior               1
# 1                  2          0   both    prior               1
# ...

# %%
path ='C:\\Users\\reece\\InstaCart Basket Analysis 4.4.23\\Data\\'
path
# Out:
# 'C:\\Users\\reece\\InstaCart Basket Analysis 4.4.23\\Data\\'

# %%
df_merged_large.to_csv(os.path.join(path, 'Prepared Data', 'orders_products_merged.csv'))

# %%
# Assuming df_merged_large is your DataFrame

# Define the file path and file name
file_path = r'C:\Users\reece\InstaCart Basket Analysis 4.4.23\Data\Prepared Data\orders_products_merged.csv'

# Save the DataFrame as CSV
df_merged_large.to_csv(file_path, index=False)

print(f"DataFrame has been saved as CSV at {file_path}")
# Out:
# DataFrame has been saved as CSV at C:\Users\reece\InstaCart Basket Analysis 4.4.23\Data\Prepared Data\orders_products_merged.csv
